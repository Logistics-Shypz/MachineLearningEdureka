# %%
# !python --version
# Out:
# Python 2.7.3 :: Continuum Analytics, Inc.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Loading Cereals Data Set and Plotting Histograms

# %%
df = pd.read_csv("cereal.csv",sep=",",header="infer")

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %%
df.values
# Out:
# array([['100% Bran', 'N', 'C', ..., 1.0, 0.33, 68.402973],
#        ['100% Natural Bran', 'Q', 'C', ..., 1.0, 1.0, 33.983678999999995],
#        ['All-Bran', 'K', 'C', ..., 1.0, 0.33, 59.425505],
#        ...,
#        ['Wheat Chex', 'R', 'C', ..., 1.0, 0.67, 49.787445],
#        ['Wheaties', 'G', 'C', ..., 1.0, 1.0, 51.592193],
#        ['Wheaties Honey Gold', 'G', 'C', ..., 1.0, 0.75, 36.187559]],
#       dtype=object)

# %%
df.head(20)
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# 5     Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
# 6                 Apple Jacks   K    C       110        2    0     125    1.0
# 7                     Basic 4   G    C       130        3    2     210    2.0
# 8                   Bran Chex   R    C        90        2    1     200    4.0
# 9                 Bran Flakes   P    C        90        3    0     210    5.0
# 10               Cap'n'Crunch   Q    C       120        1    2     220    0.0
# ...

# %%
df['name'].value_counts()
# Out:
# 100% Bran                                 1
# Nutri-Grain Almond-Raisin                 1
# Cinnamon Toast Crunch                     1
# Kix                                       1
# Grape-Nuts                                1
# Grape Nuts Flakes                         1
# Just Right Crunchy  Nuggets               1
# Product 19                                1
# Froot Loops                               1
# Apple Jacks                               1
# Count Chocula                             1
# Great Grains Pecan                        1
# Honey Nut Cheerios                        1
# Frosted Mini-Wheats                       1
# Smacks                                    1
# Life                                      1
# Strawberry Fruit Wheats                   1
# Maypo                                     1
# Cracklin' Oat Bran                        1
# Shredded Wheat 'n'Bran                    1
# Honey-comb                                1
# ...

# %%
np.random.seed(100)

# %%
sugar_df = df[['name','sugars']]

# %%
sugar_df.sugars
# Out:
# 0      6
# 1      8
# 2      5
# 3      0
# 4      8
# 5     10
# 6     14
# 7      8
# 8      6
# 9      5
# 10    12
# 11     1
# 12     9
# 13     7
# 14    13
# 15     3
# 16     2
# 17    12
# 18    13
# 19     7
# 20     0
# 21     3
# 22    10
# 23     5
# 24    13
# 25    11
# 26     7
# 27    10
# 28    12
# 29    12
#       ..
# 47     6
# 48     9
# 49     7
# 50     2
# 51    10
# 52    14
# 53     3
# 54     0
# 55     0
# 56     6
# 57    -1
# 58    12
# 59     8
# 60     6
# 61     2
# 62     3
# 63     0
# 64     0
# 65     0
# 66    15
# 67     3
# 68     5
# 69     3
# 70    14
# 71     3
# 72     3
# 73    12
# 74     3
# 75     3
# 76     8
# Name: sugars, Length: 77, dtype: int64

# %%
fig, axs = plt.subplots(1, 1, sharey=True, tight_layout=True)
axs.hist(sugar_df.sugars, bins=10,color="red")
plt.show()
# Out:
# /Users/anubhav.nanda/anaconda2/lib/python2.7/site-packages/matplotlib/figure.py:2299: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
vitamins_df = df[['name','vitamins']]

# %%
fig, axs = plt.subplots(1, 1, sharey=True, tight_layout=True)
axs.hist(vitamins_df.vitamins, bins=10,color="red")
plt.show()
# Out:
# /Users/anubhav.nanda/anaconda2/lib/python2.7/site-packages/matplotlib/figure.py:2299: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
vitamins_df.head(100)
# Out:
#                                       name  vitamins
# 0                                100% Bran        25
# 1                        100% Natural Bran         0
# 2                                 All-Bran        25
# 3                All-Bran with Extra Fiber        25
# 4                           Almond Delight        25
# 5                  Apple Cinnamon Cheerios        25
# 6                              Apple Jacks        25
# 7                                  Basic 4        25
# 8                                Bran Chex        25
# 9                              Bran Flakes        25
# 10                            Cap'n'Crunch        25
# 11                                Cheerios        25
# 12                   Cinnamon Toast Crunch        25
# 13                                Clusters        25
# 14                             Cocoa Puffs        25
# 15                               Corn Chex        25
# 16                             Corn Flakes        25
# ...

# %% [markdown]
# # Creating new column and plotting a bar plot

# %%
dict = {
    'N': 'Nabisco',
    'Q': 'Quaker Oats',
    'K': 'Kelloggs',
    'R': 'Raslston Purina',
    'G': 'General Mills',
    'P' :'Post',
    'A':'American Home Foods Products'
}

# %%
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %%
df['mfr_full'] = df['mfr'].map(dict)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 17 columns):
# name        77 non-null object
# mfr         77 non-null object
# type        77 non-null object
# calories    77 non-null int64
# protein     77 non-null int64
# fat         77 non-null int64
# sodium      77 non-null int64
# fiber       77 non-null float64
# carbo       77 non-null float64
# sugars      77 non-null int64
# potass      77 non-null int64
# vitamins    77 non-null int64
# shelf       77 non-null int64
# weight      77 non-null float64
# cups        77 non-null float64
# rating      77 non-null float64
# mfr_full    77 non-null object
# dtypes: float64(5), int64(8), object(4)
# memory usage: 10.3+ KB

# %%
mfr_name_df = df[['name','mfr_full']].groupby(['mfr_full']).count().reset_index()

# %%
def plot_bar_x():
    # this is for plotting purpose
    index = np.arange(len(label))
    plt.bar(index, no_movies)
    plt.xlabel('Genre', fontsize=5)
    plt.ylabel('No of Movies', fontsize=5)
    plt.xticks(index, label, fontsize=5, rotation=30)
    plt.title('Market Share for Each Genre 1995-2017')
    plt.show()

# %%
label = pd.Series(mfr_name_df['mfr_full'])

# %%
mfr_name_df
# Out:
#                        mfr_full  name
# 0  American Home Foods Products     1
# 1                 General Mills    22
# 2                      Kelloggs    23
# 3                       Nabisco     6
# 4                          Post     9
# 5                   Quaker Oats     8
# 6               Raslston Purina     8

# %%
index = np.arange(len(label))
plt.barh(index, pd.Series(mfr_name_df['name']), align='center', alpha=0.5)
plt.xlabel('Manufacturers', fontsize=5)
plt.ylabel('No. of cereals Manufacutred',fontsize=5)
plt.xticks(index,label,fontsize=5, rotation=30)
plt.title('Manufactures vs Count')
plt.show()
