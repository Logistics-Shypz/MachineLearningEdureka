# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
existing_df = pd.read_csv('trans_us.csv', index_col = 0, thousands  = ',')

# %%
existing_df.head()
# Out:
#                                                     1990  1991  1992  1993  \
# TB prevalence, all forms (per 100 000 populatio...
# Afghanistan                                          436   429   422   415
# Albania                                               42    40    41    42
# Algeria                                               45    44    44    43
# American Samoa                                        42    14     4    18
# Andorra                                               39    37    35    33
#
#                                                     1994  1995  1996  1997  \
# TB prevalence, all forms (per 100 000 populatio...
# Afghanistan                                          407   397   397   387
# Albania                                               42    43    42    44
# Algeria                                               43    42    43    44
# American Samoa                                        17    22     0    25
# Andorra                                               32    30    28    23
#
#                                                     1998  1999  2000  2001  \
# TB prevalence, all forms (per 100 000 populatio...
# Afghanistan                                          374   373   346   326
# Albania                                               43    42    40    34
# Algeria                                               45    46    48    49
# American Samoa                                        12     8     8     6
# Andorra                                               24    22    20    20
#
#                                                     2002  2003  2004  2005  \
# TB prevalence, all forms (per 100 000 populatio...
# Afghanistan                                          304   308   283   267
# Albania                                               32    32    29    29
# Algeria                                               50    51    52    53
# American Samoa                                         5     6     9    11
# Andorra                                               21    18    19    18
#
#                                                     2006  2007
# TB prevalence, all forms (per 100 000 populatio...
# Afghanistan                                          251   238
# Albania                                               26    22
# Algeria                                               55    56
# American Samoa                                         9     5
# Andorra                                               17    19

# %%
existing_df.index.names = ['stations']

# %%
existing_df.head()
# Out:
#                 1990  1991  1992  1993  1994  1995  1996  1997  1998  1999  \
# stations
# Afghanistan      436   429   422   415   407   397   397   387   374   373
# Albania           42    40    41    42    42    43    42    44    43    42
# Algeria           45    44    44    43    43    42    43    44    45    46
# American Samoa    42    14     4    18    17    22     0    25    12     8
# Andorra           39    37    35    33    32    30    28    23    24    22
#
#                 2000  2001  2002  2003  2004  2005  2006  2007
# stations
# Afghanistan      346   326   304   308   283   267   251   238
# Albania           40    34    32    32    29    29    26    22
# Algeria           48    49    50    51    52    53    55    56
# American Samoa     8     6     5     6     9    11     9     5
# Andorra           20    20    21    18    19    18    17    19

# %%
existing_df.columns.names = ['year']

# %%
existing_df.head()
# Out:
# year            1990  1991  1992  1993  1994  1995  1996  1997  1998  1999  \
# stations
# Afghanistan      436   429   422   415   407   397   397   387   374   373
# Albania           42    40    41    42    42    43    42    44    43    42
# Algeria           45    44    44    43    43    42    43    44    45    46
# American Samoa    42    14     4    18    17    22     0    25    12     8
# Andorra           39    37    35    33    32    30    28    23    24    22
#
# year            2000  2001  2002  2003  2004  2005  2006  2007
# stations
# Afghanistan      346   326   304   308   283   267   251   238
# Albania           40    34    32    32    29    29    26    22
# Algeria           48    49    50    51    52    53    55    56
# American Samoa     8     6     5     6     9    11     9     5
# Andorra           20    20    21    18    19    18    17    19

# %%
#existing_df = existing_df.fillna(15)
#existing_df.head()
# Out:
# year            1990  1991  1992  1993  1994  1995  1996  1997  1998  1999  \
# stations
# Afghanistan      436   429   422   415   407   397   397   387   374   373
# Albania           42    40    41    42    42    43    42    44    43    42
# Algeria           45    44    44    43    43    42    43    44    45    46
# American Samoa    42    14     4    18    17    22     0    25    12     8
# Andorra           39    37    35    33    32    30    28    23    24    22
#
# year            2000  2001  2002  2003  2004  2005  2006  2007
# stations
# Afghanistan      346   326   304   308   283   267   251   238
# Albania           40    34    32    32    29    29    26    22
# Algeria           48    49    50    51    52    53    55    56
# American Samoa     8     6     5     6     9    11     9     5
# Andorra           20    20    21    18    19    18    17    19

# %%
from sklearn.decomposition import PCA
#from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
pca = PCA()
#pca =  LDA()
pca.fit(existing_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-e2bd27cf7dcd> in <module>()
#       3 #pca = PCA()
#       4 pca =  LDA()
# ----> 5 pca.fit(existing_df)
#
# TypeError: fit() missing 1 required positional argument: 'y'

# %%
existing_2d = pca.transform(existing_df)
existing_df_2d = pd.DataFrame(existing_2d)
existing_df_2d.index = existing_df.index
#existing_df_2d.columns = ['PC1','PC2']
existing_df_2d.head()
# Out:
#                         0           1          2          3         4   \
# stations
# Afghanistan     732.215864  203.381494 -91.386254   4.101273  0.874719
# Albania        -613.296510    4.715978   3.723620  -5.497663  1.970405
# Algeria        -569.303713  -36.837051  22.974094  -7.077382 -2.342223
# American Samoa -717.082766    5.464696  28.897037 -12.102115 -3.826874
# Andorra        -661.802241   11.037736  26.829058  -4.721499 -0.923666
#
#                       5         6          7          8         9          10  \
# stations
# Afghanistan     0.275762 -3.142209 -12.810095 -12.514548  3.084263 -14.719925
# Albania        -1.057776 -4.334214   1.633313  -1.162976  2.720540  -1.520743
# Algeria         1.695158  1.561880   5.413996   0.339645  1.198487   0.695673
# American Samoa  4.185596 -1.302431  -5.457357  -5.949502 -4.693130   2.014447
# Andorra         4.200434  0.199829   4.955191  -0.550326  0.346655  -1.690722
#
#                       11         12         13        14        15        16  \
# stations
# Afghanistan    -5.839982  -5.838940   7.929728 -3.966920  2.497571 -3.920773
# Albania        -0.103493  -0.798261  -0.345024  0.731178  2.700573 -0.712622
# Algeria        -0.318449   0.850217   0.278871  0.863830  0.123622  1.349283
# American Samoa  7.743516 -12.121444 -23.631555 -0.270984  6.117575  0.929494
# Andorra        -0.718153   0.678574   1.141733 -0.883410 -1.386651 -0.485798
#
#                       17
# stations
# Afghanistan     0.206654
# Albania         0.353582
# Algeria         0.009020
# American Samoa  6.367063
# Andorra        -0.634480

# %%
print (pca.explained_variance_ratio_)
# Out:
# [  9.18087891e-01   6.05560009e-02   1.08051220e-02   2.39047545e-03
#    2.19038229e-03   1.64732996e-03   1.19502740e-03   7.97856744e-04
#    6.35817920e-04   4.61460559e-04   3.20989293e-04   2.66657191e-04
#    2.42807240e-04   1.56998807e-04   1.08464204e-04   7.07768488e-05
#    4.20518883e-05   2.38906112e-05]

# %%
var1=np.cumsum(np.round(pca.explained_variance_ratio_, decimals=4)*100)

# %%
var1
# Out:
# array([  91.81,   97.87,   98.95,   99.19,   99.41,   99.57,   99.69,
#          99.77,   99.83,   99.88,   99.91,   99.94,   99.96,   99.98,
#          99.99,  100.  ,  100.  ,  100.  ])

# %%
plt.plot(var1)
